# %%
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
x, y = make_blobs(
    n_features=2, n_samples=1000, cluster_std=2, centers=2, random_state=1
)

# %%
plt.scatter(x[:, 0], x[:, 1], alpha=0.6, c=y)
plt.scatter(-5, 0, c="r")

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
kn = KNeighborsClassifier(n_neighbors=5)

# %%
kn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
kn.score(x, y)
# Out:
# 0.998

# %%
neighbors = kn.kneighbors([[-5, 0]])
neighbors
# Out:
# (array([[0.67827132, 0.90025909, 1.1140586 , 1.19193246, 1.50207321]]),
#  array([[286, 463, 171, 479, 143]]))

# %%
_, neighbors = kn.kneighbors([[-5, 0]])

# %%
x[neighbors[0]]
# Out:
# array([[ 1.15552009,  4.66469303],
#        [-9.74308323, -4.0952479 ],
#        [-0.57426932,  0.4901517 ],
#        [-0.08910607,  3.07675433],
#        [-8.21014429, -2.05481237]])

# %%
from sklearn.datasets import make_regression

x, y = make_regression(n_features=1, noise=20, n_samples=10000, random_state=1)

plt.scatter(x, y, s=3)
plt.show()

# %%
from sklearn.datasets import make_regression

x, y = make_regression(n_features=1, noise=20, n_samples=10000, random_state=1)
# import matplotlib.pyplot as plt

plt.scatter(x, y, s=3)
plt.show()

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
kn = KNeighborsRegressor(n_neighbors=3)

# %%
kn.fit(x, y)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
kn.score(x, y)
# Out:
# 0.9657784708687274

# %%
_, neighbors = kn.kneighbors([[1]])

# %%
y[neighbors[0]]
# Out:
# array([81.98019188, 51.59353389, 62.51252132])

# %%
kn.predict([[1]])
# Out:
# array([65.36208236])

# %%
result = 81.98019188 + 51.59353389 + 62.51252132
result = result / 3
result
# Out:
# 65.36208236333333
