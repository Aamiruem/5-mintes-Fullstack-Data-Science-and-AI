# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn import datasets, metrics  # noqa: F401
import pandas as pd  # noqa: F401
from sklearn.datasets import make_classification

# %%
x,y = make_classification(n_classes=2,n_features=5,n_samples=1000,random_state=1)
plt.scatter(x[:,0],x[:,1],c=y)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state = 1)

# %%
c1 = LogisticRegression()
c1.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(c1, X_test, y_test)
plt.show()

# %%
# metrics.plot_roc_curve(c1, X_test, y_test)
metrics.plot_roc_curve(c1, X_test, y_test)   # ← this line is causing the error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 2
#       1 # metrics.plot_roc_curve(c1, X_test, y_test)
# ----> 2 metrics.plot_roc_curve(c1, X_test, y_test)   # ← this line is causing the error
#
# AttributeError: module 'sklearn.metrics' has no attribute 'plot_roc_curve'

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(c1, X_test, y_test)
plt.show()

# %%
from sklearn.metrics import RocCurveDisplay
import matplotlib.pyplot as plt

RocCurveDisplay.from_estimator(c1, X_test, y_test)
plt.title("ROC Curve")
plt.show()

# %%
from sklearn.metrics import RocCurveDisplay

y_prob = c1.predict_proba(X_test)[:, 1]
RocCurveDisplay.from_predictions(y_test, y_prob)
plt.show()

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.8.0
