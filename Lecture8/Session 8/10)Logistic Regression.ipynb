# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("G:/5 minutes Fullstack Data Science and AI/DATASETS/job.csv")
df.head(20)
# Out:
#     Years  result
# 0      22       0
# 1      25       0
# 2      47       1
# 3      52       0
# 4      46       1
# 5      56       1
# 6      55       0
# 7      60       1
# 8      62       1
# 9      61       1
# 10     18       0
# 11     28       0
# 12     27       0
# 13     29       0
# 14     49       1
# 15     55       1
# 16     25       1
# 17     58       1
# 18     19       0
# 19     18       0

# %%
x = df[["Years"]]
y = df["result"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    x, y, train_size=0.8, random_state=1
)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
print(X_test)
# Out:
#     Years
# 17     58
# 14     49
# 18     19
# 3      52
# 23     45
# 10     18

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([1, 1, 0, 1, 1, 0])

# %%
y_test
# Out:
# 17    1
# 14    1
# 18    0
# 3     0
# 23    1
# 10    0
# Name: result, dtype: int64

# %%
model.score(X_test, y_test)
# Out:
# 0.8333333333333334

# %%
import seaborn as sns

sns.regplot(x=x, y=y, logistic=True)
# Out:
# <Axes: xlabel='Years', ylabel='result'>

# %%
# pip install numpy scipy pandas
# pip install statsmodels --no-build-isolation
# python -m pip install statsmodels

# %%
import statsmodels.api as sm

print(sm.__version__)
# Out:
# 0.14.6

# %%
import seaborn as sns
import numpy as np

# scatter of original data
sns.scatterplot(x="Years", y="result", data=df)

# predicted probability curve from trained sklearn logistic regression model
X_vals = np.linspace(x["Years"].min(), x["Years"].max(), 200).reshape(-1, 1)
probs = model.predict_proba(X_vals)[:, 1]
sns.lineplot(x=X_vals.ravel(), y=probs, color="red")
# Out:
# c:\Users\My Pc\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# <Axes: xlabel='Years', ylabel='result'>
