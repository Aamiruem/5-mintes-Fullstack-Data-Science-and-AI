# %%
import pandas as pd

dataset = pd.read_csv("G:\\5 minutes Fullstack Data Science and AI\\DATASETS\\Car.csv")
x = dataset[["Age", "Income"]]
y = dataset[["Car"]]
dataset.head(10)
# Out:
#    Age  Income  Car
# 0   28   37000    0
# 1   27   88000    0
# 2   28   59000    0
# 3   32   86000    0
# 4   33  149000    1
# 5   19   21000    0
# 6   21   72000    0
# 7   26   35000    0
# 8   27   89000    0
# 9   26   86000    0

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.20, random_state=0
)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# %%
from sklearn.naive_bayes import GaussianNB

classifier = GaussianNB()
classifier.fit(x_train, y_train)

# %%
x_pred = classifier.predict(y_test)
y_pred = classifier.predict(x_test)
classifier.score(x_test, y_test)

# %%
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()
table = pd.DataFrame(iris.data, columns=iris.feature_names)
table.head()

# %%
table["target"] = iris.target
table.head()
